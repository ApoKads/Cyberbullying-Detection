# %% [markdown]
# # Install neccessary libraries

# %%
# !pip install contractions
# !pip install nltk
# !pip install autocorrect 
# !pip install --upgrade matplotlib

# %% [markdown]
# # Importing Neccessary Libraries and Dataset

# %%
# Word Processing
import string # from some string manipulation tasks
import nltk # natural language toolkit
import re # regex
import emoji
from string import punctuation # solving punctuation problems
from nltk.corpus import stopwords # stop words in sentences
from nltk.stem import WordNetLemmatizer, PorterStemmer # For stemming the sentence
from nltk.stem import SnowballStemmer # For stemming the sentence
from contractions import contractions_dict # to solve contractions
from autocorrect import Speller #correcting the spellings
nltk.download('wordnet')
nltk.download('punkt')
nltk.download('stopwords')
stop_words = set(stopwords.words('english'))


# Libraries for general uses
import numpy as np
import pandas as pd
pd.set_option('display.max_columns', None)  # No limit on columns
pd.set_option('display.max_rows', None)  

#Libraries for Visualization
import matplotlib.pyplot as plt
import seaborn as sns
# WordCloud
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator


#Data preprocessing
from sklearn import preprocessing
from sklearn.model_selection import train_test_split
# from imblearn.over_sampling import RandomOverSampler
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfTransformer
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import LabelEncoder


#Model
from sklearn.naive_bayes import MultinomialNB
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier
from xgboost import XGBClassifier # Added XGBoost
from sklearn.linear_model import LogisticRegression # Added Logistic Regression
from sklearn.svm import SVC # Added Support Vector Machine (SVM)
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\jonat\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\jonat\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\jonat\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
df = pd.read_csv('./Dataset/cyberbullying_tweets.csv')
df.head()
# Out:
#                                           tweet_text cyberbullying_type
# 0  In other words #katandandre, your food was cra...  not_cyberbullying
# 1  Why is #aussietv so white? #MKR #theblock #ImA...  not_cyberbullying
# 2  @XochitlSuckkks a classy whore? Or more red ve...  not_cyberbullying
# 3  @Jason_Gio meh. :P  thanks for the heads up, b...  not_cyberbullying
# 4  @RudhoeEnglish This is an ISIS account pretend...  not_cyberbullying

# %%
df.isnull().sum()
# Out:
# tweet_text            0
# cyberbullying_type    0
# dtype: int64

# %%
df['cyberbullying_type'].value_counts()
# Out:
# religion               7998
# age                    7992
# gender                 7973
# ethnicity              7961
# not_cyberbullying      7945
# other_cyberbullying    7823
# Name: cyberbullying_type, dtype: int64

# %%
df.drop(df[df['cyberbullying_type'] == 'other_cyberbullying'].index, inplace = True)
df['cyberbullying_type'].value_counts()
# Out:
# religion             7998
# age                  7992
# gender               7973
# ethnicity            7961
# not_cyberbullying    7945
# Name: cyberbullying_type, dtype: int64

# %% [markdown]
# # Preprocessing

# %%
df = df.rename(columns={'tweet_text': 'text', 'cyberbullying_type': 'sentiment'})

# %%
df.sample(10)
# Out:
#                                                     text          sentiment
# 6598     @JJLeJet_Plane is it going to be hot Wednesday?  not_cyberbullying
# 5212   RT @ggautoblocker: Roses are red My hair is bl...  not_cyberbullying
# 7740   RT @Pyrrha108: . #IslamicState murders gay men...  not_cyberbullying
# 39271  One year, I had a principal who was a bully in...                age
# 12044  Omg Kat and Andre are cooking at Mandurah crab...             gender
# 35040  this tweet is for the girls who bullied me in ...                age
# 21065  So you don't have an answer for why muslims ha...           religion
# 16137  @congressman_aly Somewhere in the world Muslim...           religion
# 38531  I grew up in the 50s-60s. We had telephones, p...                age
# 11443  I'm trying so hard to be charming - Annie. I h...             gender

# %%
df["sentiment"].replace({"religion": 1, "age": 2, "gender": 3, "ethnicity": 4, "not_cyberbullying": 5}, inplace=True)

# %%
sentiments = ["religion","age","gender","ethnicity","not bullying"]

# %% [markdown]
# Preprocessing Function

# %%
stop_words = set(stopwords.words('english'))

#Remove punctuations, links, stopwords, mentions and \r\n new line characters
def strip_all_entities(text): 
    text = text.replace('\r', '').replace('\n', ' ').lower() #remove \n and \r and lowercase
    text = re.sub(r"(?:\@|https?\://)\S+", "", text) #remove links and mentions
    text = re.sub(r'[^\x00-\x7f]',r'', text) #remove non utf8/ascii characters such as '\x9a\x91\x97\x9a\x97'
    banned_list= string.punctuation
    table = str.maketrans('', '', banned_list)
    text = text.translate(table)
    text = [word for word in text.split() if word not in stop_words]
    text = ' '.join(text)
    text =' '.join(word for word in text.split() if len(word) < 14) # remove words longer than 14 characters
    return text


def decontract(text):
    text = re.sub(r"can\'t", "can not", text)
    text = re.sub(r"n\'t", " not", text)
    text = re.sub(r"\'re", " are", text)
    text = re.sub(r"\'s", " is", text)
    text = re.sub(r"\'d", " would", text)
    text = re.sub(r"\'ll", " will", text)
    text = re.sub(r"\'t", " not", text)
    text = re.sub(r"\'ve", " have", text)
    text = re.sub(r"\'m", " am", text)
    return text


#clean hashtags at the end of the sentence, and keep those in the middle of the sentence by removing just the "#" symbol
def clean_hashtags(tweet):
    new_tweet = " ".join(word.strip() for word in re.split('#(?!(?:hashtag)\b)[\w-]+(?=(?:\s+#[\w-]+)*\s*$)', tweet)) #remove last hashtags
    new_tweet2 = " ".join(word.strip() for word in re.split('#|_', new_tweet)) #remove hashtags symbol from words in the middle of the sentence
    return new_tweet2

def filter_chars(a):
    sent = []
    for word in a.split(' '):
        if ('$' in word) | ('&' in word):
            sent.append('')
        else:
            sent.append(word)
    return ' '.join(sent)

def remove_mult_spaces(text):
    return re.sub("\s\s+" , " ", text)

def stemmer(text):
    tokenized = nltk.word_tokenize(text)
    ps = PorterStemmer()
    return ' '.join([ps.stem(words) for words in tokenized])

#Lemmatization 
def lemmatize(text):
    tokenized = nltk.word_tokenize(text)
    lm = WordNetLemmatizer()
    return ' '.join([lm.lemmatize(words) for words in tokenized])

def preprocess(text):
    text = decontract(text)
    text = strip_all_entities(text)
    text = clean_hashtags(text)
    text = filter_chars(text)
    text = remove_mult_spaces(text)
    text = stemmer(text)
    return text

# %%
texts_cleaned = []
for t in df.text:
    texts_cleaned.append(preprocess(t))

# %%
df['text_clean'] = texts_cleaned

# %%
df.sample(100)
# Out:
#                                                     text  sentiment  \
# 18593  First of all, it's not the Muslims that made t...          1
# 5367   First impression I want someone to have of me ...          5
# 17732  Ha-ha-ha-ha-ha! Islam is against evil If you r...          1
# 23463  @asem_1994 And I know that Umar imposed the co...          1
# 19248  Stupid apologetic Hindus who have converted to...          1
# 20396  When an idiot stomps around my country destroy...          1
# 863    Congrats to @Bigplaycj on breaking the great @...          5
# 32092  I no longer site in school, so prefect of soci...          2
# 14505  If my dad could stop making jokes about gay pe...          3
# 41381  Much obsessed about color - race. All have mad...          4
# 32064  It’s crazy cause ya girl was getting bullied u...          2
# 37966  I am willing to bet that in high school @RepAO...          2
# 6616   @SarahPaIinUSA the bible? The one with the ang...          5
# ...

# %%
df["text_clean"].duplicated().sum()
df.drop_duplicates("text_clean", inplace=True)

# %%
df.sentiment.value_counts()
# Out:
# 1    7946
# 2    7884
# 4    7746
# 5    7637
# 3    7607
# Name: sentiment, dtype: int64

# %%
text_len = []
for text in df.text_clean:
    tweet_len = len(text.split())
    text_len.append(tweet_len)

# %%
df['text_len'] = text_len

# %%
df.head()
# Out:
#                                                 text  sentiment  \
# 0  In other words #katandandre, your food was cra...          5
# 1  Why is #aussietv so white? #MKR #theblock #ImA...          5
# 2  @XochitlSuckkks a classy whore? Or more red ve...          5
# 3  @Jason_Gio meh. :P  thanks for the heads up, b...          5
# 4  @RudhoeEnglish This is an ISIS account pretend...          5
#
#                                           text_clean  text_len
# 0                 word katandandr food crapilici mkr         5
# 1  aussietv white mkr theblock today sunris studi...        10
# 2                     classi whore red velvet cupcak         5
# 3  meh p thank head concern anoth angri dude twitter         9
# 4  isi account pretend kurdish account like islam...         8

# %%
plt.figure(figsize=(7,5))
ax = sns.countplot(x='text_len', data=df[df['text_len']<10], palette='mako')
plt.title('Count of tweets with less than 10 words', fontsize=20)
plt.yticks([])
ax.bar_label(ax.containers[0])
plt.ylabel('count')
plt.xlabel('')
plt.show()

# %%
df = df.drop(df[df['text_len'] == 0].index)

# %%
plt.figure(figsize=(7,5))
ax = sns.countplot(x='text_len', data=df[df['text_len']<10], palette='mako')
plt.title('Count of tweets with less than 10 words', fontsize=20)
plt.yticks([])
ax.bar_label(ax.containers[0])
plt.ylabel('count')
plt.xlabel('')
plt.show()

# %%
df = df[df['text_len'] < 100]

# %%
lenc = LabelEncoder()
df.sentiment = lenc.fit_transform(df.sentiment)

for c in range(len(lenc.classes_)):
    string = ""
    for i in df[df.sentiment == c].text_clean.values:
        string = string + " " + i.strip()

    wordcloud = WordCloud(width = 800, height = 800,
                background_color ='white',
                min_font_size = 10).generate(string)
    plt.figure(figsize = (8, 8), facecolor = None)
    plt.imshow(wordcloud)
    plt.axis("off")
    plt.tight_layout(pad = 0)
    plt.title(lenc.classes_[c])
    plt.show()
    del string

# %%
len(df['text_clean'])
# Out:
# 38810

# %%
from sklearn.model_selection import train_test_split
# train and test
X_train_raw, X_test_raw, y_train, y_test = train_test_split(df['text_clean'], df['sentiment'], test_size=0.20, stratify=df['sentiment'], random_state=42)

# %%
from sklearn.feature_extraction.text import CountVectorizer, TfidfTransformer

# 1. CountVectorizer dengan n-gram (unigram + bigram)
vectorizer = CountVectorizer(ngram_range=(1, 3))  # <-- Tambahkan ngram_range
X_train_counts = vectorizer.fit_transform(X_train_raw)
X_test_counts = vectorizer.transform(X_test_raw)

# 2. TF-IDF Transform
tfidf_transformer = TfidfTransformer()
X_train= tfidf_transformer.fit_transform(X_train_counts)
X_test = tfidf_transformer.transform(X_test_counts)

# Cek fitur (kata/n-gram) yang dihasilkan
print("Contoh fitur (vocabulary):", vectorizer.get_feature_names_out()[:20])  # Tampilkan 20 fitur pertama
# Out:
# Contoh fitur (vocabulary): ['00' '00 bleak' '00 came' '00 came back' '00 one' '00 one first' '000'
#  '000 serbian' '000 serbian civilian' '0006' '0006 muslim'
#  '0006 muslim accord' '0021' '0021 made' '0021 made sever' '00you'
#  '00you mad' '00you mad rt' '01' '01 death']

# %%
# X_tf
X_train.shape
# Out:
# (31048, 617512)

# %%
from sklearn.feature_selection import SelectKBest, chi2

# 3. SelectKBest dengan Chi2
selector = SelectKBest(score_func=chi2, k=1000)  # Pilih 500 fitur terbaik
X_train_selected = selector.fit_transform(X_train, y_train)  # y_train harus disediakan
X_test_selected = selector.transform(X_test)

# (Opsional) Cek fitur-fitur terpilih
selected_feature_indices = selector.get_support(indices=True)
selected_features = vectorizer.get_feature_names_out()[selected_feature_indices]
print("Contoh fitur terpilih:", selected_features[:20])  # Tampilkan 20 fitur terpilih pertama
# Out:
# Contoh fitur terpilih: ['100 islam' '100 islam terrorist' '1400' '1400 year' '1400 year ago' '16'
#  '2018' '24' '24 da' '24 da chamada' '2gether' '411pain' '4th grade' '5so'
#  '5so fuck' '5so fuck dumb' '6th' '6th grade' '72' '7th centuri']

# %%
X_train = X_train_selected.copy()
X_test = X_test_selected.copy()

# %%
X_train.shape
# Out:
# (31048, 5000)

# %%
y_train.value_counts()
# Out:
# 0    6357
# 1    6306
# 3    6195
# 4    6107
# 2    6083
# Name: sentiment, dtype: int64

# %%
nb_clf = MultinomialNB()
nb_clf.fit(X_train, y_train)
# Out:
# MultinomialNB()

# %%
from sklearn.metrics import classification_report
nb_pred = nb_clf.predict(X_test)
nb_train = nb_clf.predict(X_train)
print('Classification Report for Naive Bayes:\n',classification_report(y_test, nb_pred, target_names=sentiments))
# Out:
# Classification Report for Naive Bayes:
#                precision    recall  f1-score   support
#
#     religion       0.76      0.98      0.86      1589
#          age       0.83      0.98      0.90      1577
#       gender       0.92      0.81      0.86      1521
#    ethnicity       0.92      0.94      0.93      1548
# not bullying       0.82      0.49      0.61      1527
#
#     accuracy                           0.84      7762
#    macro avg       0.85      0.84      0.83      7762
# weighted avg       0.85      0.84      0.83      7762

# %%
print('Classification Report for Naive Bayes:\n',classification_report(y_train, nb_train, target_names=sentiments))
# Out:
# Classification Report for Naive Bayes:
#                precision    recall  f1-score   support
#
#     religion       0.78      0.99      0.87      6357
#          age       0.84      0.98      0.90      6306
#       gender       0.93      0.82      0.87      6083
#    ethnicity       0.92      0.95      0.93      6195
# not bullying       0.83      0.51      0.63      6107
#
#     accuracy                           0.85     31048
#    macro avg       0.86      0.85      0.84     31048
# weighted avg       0.86      0.85      0.84     31048

# %%
rf_clf = RandomForestClassifier()
rf_clf.fit(X_train, y_train)
# Out:
# RandomForestClassifier()

# %%
from sklearn.metrics import classification_report, accuracy_score

rf_pred = rf_clf.predict(X_test)
rf_train = rf_clf.predict(X_train)
print('Classification Report for Random Forest:\n',classification_report(y_test, rf_pred, target_names=sentiments))
print(f"Accuracy: {accuracy_score(y_test, rf_pred):.4f}")
# Out:
# Classification Report for Random Forest:
#                precision    recall  f1-score   support
#
#     religion       0.96      0.95      0.96      1589
#          age       0.99      0.97      0.98      1577
#       gender       0.90      0.86      0.88      1521
#    ethnicity       1.00      0.99      0.99      1548
# not bullying       0.79      0.87      0.83      1527
#
#     accuracy                           0.93      7762
#    macro avg       0.93      0.92      0.93      7762
# weighted avg       0.93      0.93      0.93      7762
#
# Accuracy: 0.9253

# %%
print('Classification Report for Random Forest:\n',classification_report(y_train, rf_train, target_names=sentiments,digits=4))
# Out:
# Classification Report for Random Forest:
#                precision    recall  f1-score   support
#
#     religion     0.9998    0.9998    0.9998      6357
#          age     1.0000    0.9990    0.9995      6306
#       gender     0.9997    0.9888    0.9942      6083
#    ethnicity     1.0000    1.0000    1.0000      6195
# not bullying     0.9879    0.9995    0.9937      6107
#
#     accuracy                         0.9975     31048
#    macro avg     0.9975    0.9974    0.9974     31048
# weighted avg     0.9975    0.9975    0.9975     31048

# %%
from xgboost import XGBClassifier
from sklearn.metrics import classification_report, accuracy_score

# Initialize with common parameters
xgb_clf = XGBClassifier()

# Train
xgb_clf.fit(X_train, y_train)

# Predict and evaluate
y_pred_xgb = xgb_clf.predict(X_test)
y_train_xgb = xgb_clf.predict(X_train)
print("XGBoost Results:")
print(classification_report(y_test, y_pred_xgb))
print(f"Accuracy: {accuracy_score(y_test, y_pred_xgb):.4f}")
# Out:
# XGBoost Results:
#               precision    recall  f1-score   support
#
#            0       0.97      0.92      0.95      1589
#            1       0.99      0.96      0.98      1577
#            2       0.94      0.84      0.88      1521
#            3       1.00      0.98      0.99      1548
#            4       0.76      0.92      0.83      1527
#
#     accuracy                           0.92      7762
#    macro avg       0.93      0.92      0.93      7762
# weighted avg       0.93      0.92      0.93      7762
#
# Accuracy: 0.9244

# %%
print(f"Accuracy: {accuracy_score(y_train, y_train_xgb):.4f}")
print(classification_report(y_train, y_train_xgb))
# Out:
# Accuracy: 0.9585
#               precision    recall  f1-score   support
#
#            0       0.98      0.96      0.97      6357
#            1       1.00      0.99      0.99      6306
#            2       0.98      0.89      0.93      6083
#            3       1.00      0.99      1.00      6195
#            4       0.86      0.96      0.90      6107
#
#     accuracy                           0.96     31048
#    macro avg       0.96      0.96      0.96     31048
# weighted avg       0.96      0.96      0.96     31048

# %%
from sklearn.ensemble import AdaBoostClassifier
from sklearn.tree import DecisionTreeClassifier

# Using DecisionTree as base estimator (default is DecisionTree with max_depth=1)
ada_clf = AdaBoostClassifier()

# Train
ada_clf.fit(X_train, y_train)

# Predict and evaluate
y_pred_ada = ada_clf.predict(X_test)
y_train_ada = ada_clf.predict(X_train)
print("\nAdaBoost Results:")
print(classification_report(y_test, y_pred_ada))
print(f"Accuracy: {accuracy_score(y_test, y_pred_ada):.4f}")
# Out:
# AdaBoost Results:
#               precision    recall  f1-score   support
#
#            0       0.95      0.94      0.94      1589
#            1       0.94      0.92      0.93      1577
#            2       0.96      0.75      0.84      1521
#            3       0.98      0.97      0.98      1548
#            4       0.70      0.88      0.78      1527
#
#     accuracy                           0.89      7762
#    macro avg       0.91      0.89      0.90      7762
# weighted avg       0.91      0.89      0.90      7762
#
# Accuracy: 0.8941

# %%
print(classification_report(y_train, y_train_ada))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.95      0.94      0.95      6357
#            1       0.95      0.96      0.96      6306
#            2       0.97      0.78      0.86      6083
#            3       0.99      0.97      0.98      6195
#            4       0.74      0.89      0.81      6107
#
#     accuracy                           0.91     31048
#    macro avg       0.92      0.91      0.91     31048
# weighted avg       0.92      0.91      0.91     31048

# %%
# from sklearn.svm import SVC

# svm_clf = SVC()  # atau 'rbf', 'poly' tergantung kebutuhan
# svm_clf.fit(X_train, y_train)

# y_pred_svm = svm_clf.predict(X_test)
# y_train_svm = svm_clf.predict(X_train)
# print("\nSVM Results:")
# print(classification_report(y_test, y_pred_svm))
# print(f"Accuracy: {accuracy_score(y_test, y_pred_svm):.4f}")

# %%
from sklearn.neighbors import KNeighborsClassifier
knn_clf = KNeighborsClassifier(n_neighbors=5)  # kamu bisa sesuaikan n_neighbors
knn_clf.fit(X_train, y_train)

y_pred_knn = knn_clf.predict(X_test)
y_train_knn = knn_clf.predict(X_train)
print("\nKNN Results:")
print(classification_report(y_test, y_pred_knn))
print(f"Accuracy: {accuracy_score(y_test, y_pred_knn):.4f}")
# Out:
# KNN Results:
#               precision    recall  f1-score   support
#
#            0       0.91      0.79      0.85      1589
#            1       0.95      0.78      0.86      1577
#            2       0.86      0.77      0.82      1521
#            3       0.97      0.91      0.94      1548
#            4       0.57      0.84      0.68      1527
#
#     accuracy                           0.82      7762
#    macro avg       0.85      0.82      0.83      7762
# weighted avg       0.85      0.82      0.83      7762
#
# Accuracy: 0.8191

# %%
print(classification_report(y_train, y_train_knn))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.97      0.72      0.83      6357
#            1       0.98      0.72      0.83      6306
#            2       0.90      0.78      0.84      6083
#            3       0.98      0.85      0.91      6195
#            4       0.52      0.94      0.67      6107
#
#     accuracy                           0.80     31048
#    macro avg       0.87      0.80      0.81     31048
# weighted avg       0.87      0.80      0.81     31048

# %%
from sklearn.linear_model import LogisticRegression

logreg_clf = LogisticRegression(max_iter=1000, random_state=42)

# Training
logreg_clf.fit(X_train, y_train)

# Prediksi
y_pred_logreg = logreg_clf.predict(X_test)
y_train_logreg = logreg_clf.predict(X_train)

print("\nLogistic Regression Results:")
print(classification_report(y_test, y_pred_logreg))
print(f"Accuracy: {accuracy_score(y_test, y_pred_logreg):.4f}")
# Out:
# Logistic Regression Results:
#               precision    recall  f1-score   support
#
#            0       0.93      0.96      0.95      1589
#            1       0.89      0.99      0.94      1577
#            2       0.91      0.85      0.88      1521
#            3       0.96      0.99      0.97      1548
#            4       0.82      0.72      0.77      1527
#
#     accuracy                           0.90      7762
#    macro avg       0.90      0.90      0.90      7762
# weighted avg       0.90      0.90      0.90      7762
#
# Accuracy: 0.9031

# %%
print(classification_report(y_train, y_train_logreg))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.96      0.95      0.95      6357
#            1       0.96      0.96      0.96      6306
#            2       0.96      0.83      0.89      6083
#            3       0.98      0.97      0.98      6195
#            4       0.77      0.89      0.82      6107
#
#     accuracy                           0.92     31048
#    macro avg       0.93      0.92      0.92     31048
# weighted avg       0.93      0.92      0.92     31048

# %%
from sklearn.metrics import accuracy_score, f1_score
# import pandas as pd

# # Buat dictionary untuk menyimpan hasil akurasi dan f1-score
# results = {
#     'Naive Bayes': {
#         'Accuracy': accuracy_score(y_test, nb_pred),
#         'F1-Score': f1_score(y_test, nb_pred, average='weighted')
#     },
#     'Random Forest': {
#         'Accuracy': accuracy_score(y_test, rf_pred),
#         'F1-Score': f1_score(y_test, rf_pred, average='weighted')
#     },
#     'XGBoost': {
#         'Accuracy': accuracy_score(y_test, y_pred_xgb),
#         'F1-Score': f1_score(y_test, y_pred_xgb, average='weighted')
#     },
#     'AdaBoost': {
#         'Accuracy': accuracy_score(y_test, y_pred_ada),
#         'F1-Score': f1_score(y_test, y_pred_ada, average='weighted')
#     },
#     'SVM': {
#         'Accuracy': accuracy_score(y_test, y_pred_svm),
#         'F1-Score': f1_score(y_test, y_pred_svm, average='weighted')
#     },
#     'KNN': {
#         'Accuracy': accuracy_score(y_test, y_pred_knn),
#         'F1-Score': f1_score(y_test, y_pred_knn, average='weighted')
#     },
#     'Logistic': {
#         'Accuracy': accuracy_score(y_test, y_pred_logreg),
#         'F1-Score': f1_score(y_test, y_pred_logreg, average='weighted')
#     }
# }

# # Convert dictionary ke DataFrame
# results_df = pd.DataFrame.from_dict(results, orient='index').reset_index()
# results_df.columns = ['Model', 'Accuracy', 'F1-Score']

# # Urutkan berdasarkan Accuracy
# results_df = results_df.sort_values(by='Accuracy', ascending=False)

# # Tampilkan
# # print(results_df)
# results_df

# %%
# from sklearn.ensemble import AdaBoostClassifier
# from sklearn.tree import DecisionTreeClassifier

# # Using DecisionTree as base estimator (default is DecisionTree with max_depth=1)
# ada_clf = AdaBoostClassifier()

# # Train
# ada_clf.fit(X_train, y_train)

# # Predict and evaluate
# y_pred_ada = ada_clf.predict(X_test)
# print("\nAdaBoost Results:")
# print(classification_report(y_test, y_pred_ada))
# print(f"Accuracy: {accuracy_score(y_test, y_pred_ada):.4f}")

# saya ada adaboost,xgboost , random forest, svm

# %%
from sklearn.ensemble import StackingClassifier

base_learners = [
    ('rf', RandomForestClassifier()),
    ('xgb', XGBClassifier()),
    ('svm', SVC(probability=True))  # probability=True penting untuk stacking
]

meta_learner = LogisticRegression(max_iter=1000, random_state=42)

stacking_clf = StackingClassifier(
    estimators=base_learners,
    final_estimator=meta_learner,
    passthrough=False,         # Kalau True, fitur asli ikut masuk ke meta-learner
    # cv=5,                      # 5-fold cross-validation untuk base learners
    # n_jobs=-1
)

# Train
stacking_clf.fit(X_train, y_train)
# Out:
# StackingClassifier(estimators=[('rf', RandomForestClassifier()),
#                                ('xgb',
#                                 XGBClassifier(base_score=None, booster=None,
#                                               callbacks=None,
#                                               colsample_bylevel=None,
#                                               colsample_bynode=None,
#                                               colsample_bytree=None,
#                                               early_stopping_rounds=None,
#                                               enable_categorical=False,
#                                               eval_metric=None, gamma=None,
#                                               gpu_id=None, grow_policy=None,
#                                               importance_type=None,
#                                               interaction_constraints=N...
#                                               max_cat_to_onehot=None,
# ...

# %%
y_pred_stack = stacking_clf.predict(X_test)

print("\nStacking Classifier Results (RF + XGB + SVM):")
print(classification_report(y_test, y_pred_stack))
print(f"Accuracy : {accuracy_score(y_test, y_pred_stack):.4f}")
print(f"F1-Score : {f1_score(y_test, y_pred_stack, average='weighted'):.4f}")
# Out:
# Stacking Classifier Results (RF + XGB + SVM):
#               precision    recall  f1-score   support
#
#            0       0.97      0.94      0.96      1589
#            1       0.99      0.96      0.98      1577
#            2       0.93      0.86      0.89      1521
#            3       0.99      0.99      0.99      1548
#            4       0.79      0.90      0.84      1527
#
#     accuracy                           0.93      7762
#    macro avg       0.93      0.93      0.93      7762
# weighted avg       0.94      0.93      0.93      7762
#
# Accuracy : 0.9313
# F1-Score : 0.9324

# %%
from sklearn.metrics import confusion_matrix,classification_report,roc_curve,auc

cm = confusion_matrix(y_test, y_pred_stack)
print("Confusion Matrix:")
plt.figure(figsize=(6,6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues')
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Stacking Models Confusion Matrix')
plt.show()
# Out:
# Confusion Matrix:

# %%
# from sklearn.metrics import accuracy_score, f1_score, precision_score, recall_score
# import pandas as pd

# # Buat dictionary dengan metrik untuk TRAINING data
# train_results = {
#     'Naive Bayes': {
#         'Accuracy': accuracy_score(y_train, nb_clf.predict(X_train)),
#         'F1-Score': f1_score(y_train, nb_clf.predict(X_train), average='weighted'),
#         'Precision': precision_score(y_train, nb_clf.predict(X_train), average='weighted'),
#         'Recall': recall_score(y_train, nb_clf.predict(X_train), average='weighted')
#     },
#     'Random Forest': {
#         'Accuracy': accuracy_score(y_train, rf_clf.predict(X_train)),
#         'F1-Score': f1_score(y_train, rf_clf.predict(X_train), average='weighted'),
#         'Precision': precision_score(y_train, rf_clf.predict(X_train), average='weighted'),
#         'Recall': recall_score(y_train, rf_clf.predict(X_train), average='weighted')
#     },
#     'XGBoost': {
#         'Accuracy': accuracy_score(y_train, xgb_clf.predict(X_train)),
#         'F1-Score': f1_score(y_train, xgb_clf.predict(X_train), average='weighted'),
#         'Precision': precision_score(y_train, xgb_clf.predict(X_train), average='weighted'),
#         'Recall': recall_score(y_train, xgb_clf.predict(X_train), average='weighted')
#     },
#     'AdaBoost': {
#         'Accuracy': accuracy_score(y_train, ada_clf.predict(X_train)),
#         'F1-Score': f1_score(y_train, ada_clf.predict(X_train), average='weighted'),
#         'Precision': precision_score(y_train, ada_clf.predict(X_train), average='weighted'),
#         'Recall': recall_score(y_train, ada_clf.predict(X_train), average='weighted')
#     },
#     'SVM': {
#         'Accuracy': accuracy_score(y_train, svm_clf.predict(X_train)),
#         'F1-Score': f1_score(y_train, svm_clf.predict(X_train), average='weighted'),
#         'Precision': precision_score(y_train, svm_clf.predict(X_train), average='weighted'),
#         'Recall': recall_score(y_train, svm_clf.predict(X_train), average='weighted')
#     },
#     'KNN': {
#         'Accuracy': accuracy_score(y_train, knn_clf.predict(X_train)),
#         'F1-Score': f1_score(y_train, knn_clf.predict(X_train), average='weighted'),
#         'Precision': precision_score(y_train, knn_clf.predict(X_train), average='weighted'),
#         'Recall': recall_score(y_train, knn_clf.predict(X_train), average='weighted')
#     },
#     'Logistic': {
#         'Accuracy': accuracy_score(y_train, logreg_clf.predict(X_train)),
#         'F1-Score': f1_score(y_train, logreg_clf.predict(X_train), average='weighted'),
#         'Precision': precision_score(y_train, logreg_clf.predict(X_train), average='weighted'),
#         'Recall': recall_score(y_train, logreg_clf.predict(X_train), average='weighted')
#     },
#     'Ensemble Stacking': {
#         'Accuracy': accuracy_score(y_train, stacking_clf.predict(X_train)),
#         'F1-Score': f1_score(y_train, stacking_clf.predict(X_train), average='weighted'),
#         'Precision': precision_score(y_train, stacking_clf.predict(X_train), average='weighted'),
#         'Recall': recall_score(y_train, stacking_clf.predict(X_train), average='weighted')
#     }
# }

# # Convert dictionary ke DataFrame
# train_results_df = pd.DataFrame.from_dict(train_results, orient='index').reset_index()
# train_results_df.columns = ['Model', 'Accuracy', 'F1-Score', 'Precision', 'Recall']

# # Urutkan berdasarkan Accuracy
# train_results_df = train_results_df.sort_values(by='Accuracy', ascending=False)

# # Tampilkan
# train_results_df

# %%
from sklearn.metrics import accuracy_score, f1_score, precision_score, recall_score
import pandas as pd

# Buat dictionary dengan semua metrik
results = {
    'Naive Bayes': {
        'Accuracy': accuracy_score(y_test, nb_pred),
        'F1-Score': f1_score(y_test, nb_pred, average='weighted'),
        'Precision': precision_score(y_test, nb_pred, average='weighted'),
        'Recall': recall_score(y_test, nb_pred, average='weighted')
    },
    'Random Forest': {
        'Accuracy': accuracy_score(y_test, rf_pred),
        'F1-Score': f1_score(y_test, rf_pred, average='weighted'),
        'Precision': precision_score(y_test, rf_pred, average='weighted'),
        'Recall': recall_score(y_test, rf_pred, average='weighted')
    },
    'XGBoost': {
        'Accuracy': accuracy_score(y_test, y_pred_xgb),
        'F1-Score': f1_score(y_test, y_pred_xgb, average='weighted'),
        'Precision': precision_score(y_test, y_pred_xgb, average='weighted'),
        'Recall': recall_score(y_test, y_pred_xgb, average='weighted')
    },
    'AdaBoost': {
        'Accuracy': accuracy_score(y_test, y_pred_ada),
        'F1-Score': f1_score(y_test, y_pred_ada, average='weighted'),
        'Precision': precision_score(y_test, y_pred_ada, average='weighted'),
        'Recall': recall_score(y_test, y_pred_ada, average='weighted')
    },
    # 'SVM': {
    #     'Accuracy': accuracy_score(y_test, y_pred_svm),
    #     'F1-Score': f1_score(y_test, y_pred_svm, average='weighted'),
    #     'Precision': precision_score(y_test, y_pred_svm, average='weighted'),
    #     'Recall': recall_score(y_test, y_pred_svm, average='weighted')
    # },
    'KNN': {
        'Accuracy': accuracy_score(y_test, y_pred_knn),
        'F1-Score': f1_score(y_test, y_pred_knn, average='weighted'),
        'Precision': precision_score(y_test, y_pred_knn, average='weighted'),
        'Recall': recall_score(y_test, y_pred_knn, average='weighted')
    },
    'Logistic': {
        'Accuracy': accuracy_score(y_test, y_pred_logreg),
        'F1-Score': f1_score(y_test, y_pred_logreg, average='weighted'),
        'Precision': precision_score(y_test, y_pred_logreg, average='weighted'),
        'Recall': recall_score(y_test, y_pred_logreg, average='weighted')
    },
    'Ensemble Stacking':{
        'Accuracy': accuracy_score(y_test, y_pred_stack),
        'F1-Score': f1_score(y_test, y_pred_stack, average='weighted'),
        'Precision': precision_score(y_test, y_pred_stack, average='weighted'),
        'Recall': recall_score(y_test, y_pred_stack, average='weighted')
    }
}

# Convert dictionary ke DataFrame
results_df = pd.DataFrame.from_dict(results, orient='index').reset_index()
results_df.columns = ['Model', 'Accuracy', 'F1-Score', 'Precision', 'Recall']

# Urutkan berdasarkan Accuracy
results_df = results_df.sort_values(by='Accuracy', ascending=False)

# Tampilkan
results_df
# Out:
#                Model  Accuracy  F1-Score  Precision    Recall
# 6  Ensemble Stacking  0.931332  0.932415   0.935492  0.931332
# 1      Random Forest  0.925277  0.926241   0.928164  0.925277
# 2            XGBoost  0.924375  0.926189   0.932350  0.924375
# 5           Logistic  0.903118  0.900474   0.901015  0.903118
# 3           AdaBoost  0.894099  0.896142   0.907334  0.894099
# 0        Naive Bayes  0.842309  0.831565   0.847594  0.842309
# 4                KNN  0.819119  0.827804   0.853478  0.819119

# %%
from sklearn.metrics import roc_curve, auc
from sklearn.preprocessing import label_binarize
import matplotlib.pyplot as plt
import numpy as np

# Binarize y_test (misal: kelas = 0, 1, 2)
classes = np.unique(y_test)
y_test_bin = label_binarize(y_test, classes=classes)
n_classes = y_test_bin.shape[1]

# Siapkan model dan nama
models = [logreg_clf, rf_clf, xgb_clf, knn_clf, ada_clf, nb_clf]
model_names = ['Logistic', 'Random Forest', 'XGBoost', 'KNN', 'AdaBoost', 'Naive Bayes']

plt.figure(figsize=(10, 8))

# Loop tiap model
for model, name in zip(models, model_names):
    # Prediksi probabilitas
    y_score = model.predict_proba(X_test)
    
    # Hitung micro-average ROC
    fpr, tpr, _ = roc_curve(y_test_bin.ravel(), y_score.ravel())
    roc_auc = auc(fpr, tpr)
    
    plt.plot(fpr, tpr, lw=2, label=f'{name} (AUC = {roc_auc:.2f})')

# Garis baseline
plt.plot([0, 1], [0, 1], color='gray', linestyle='--', lw=2)

plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Multiclass ROC Curve (Micro-Averaged) for Multiple Models')
plt.legend(loc='lower right')
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
# plt.figure(figsize=(12, 7)) # Ukuran plot

# # Membuat bar chart
# plt.bar(results_df['Model'], results_df['Accuracy'], color='skyblue')

# # Menambahkan label nilai akurasi di atas setiap bar
# for i, acc in enumerate(results_df['Accuracy']):
#     plt.text(i, acc + 0.005, f'{acc:.4f}', ha='center', va='bottom', fontsize=9)

# plt.xlabel('Model')
# plt.ylabel('Akurasi')
# plt.title('Perbandingan Akurasi Model Klasifikasi')
# plt.ylim(results_df['Accuracy'].min() * 0.95, 1.0) # Sesuaikan batas Y untuk visualisasi yang lebih baik
# plt.xticks(rotation=45, ha='right') # Rotasi label X agar tidak tumpang tindih
# plt.tight_layout() # Mengatur tata letak agar semua elemen terlihat
# plt.grid(axis='y', linestyle='--', alpha=0.7) # Menambahkan grid horizontal

# # Simpan plot (opsional)
# plt.savefig('akurasi_model_perbandingan.png')

# # Tampilkan plot
# plt.show()

# %%
# from sklearn.metrics import roc_curve, auc
# from sklearn.preprocessing import label_binarize
# import matplotlib.pyplot as plt
# import numpy as np

# # Binarize y_test (misal: kelas = 0, 1, 2, 3, 4)
# classes = np.unique(y_test)
# y_test_bin = label_binarize(y_test, classes=classes)
# n_classes = y_test_bin.shape[1] # Jumlah kelas

# # Siapkan model dan nama
# models = [logreg_clf, rf_clf, xgb_clf, knn_clf, ada_clf, nb_clf, stacking_clf]
# model_names = ['Logistic', 'Random Forest', 'XGBoost', 'KNN', 'AdaBoost', 'Naive Bayes', 'Stacking Method']

# plt.figure(figsize=(12, 10)) # Ukuran plot lebih besar

# # Loop tiap model
# for model, name in zip(models, model_names):
#     # Prediksi probabilitas untuk setiap kelas
#     y_score = model.predict_proba(X_test)

#     # Hitung ROC curve dan AUC untuk setiap kelas (One-vs-Rest)
#     fpr = dict()
#     tpr = dict()
#     roc_auc = dict()
#     for i in range(n_classes):
#         fpr[i], tpr[i], _ = roc_curve(y_test_bin[:, i], y_score[:, i])
#         roc_auc[i] = auc(fpr[i], tpr[i])

#     # Hitung Macro-average ROC AUC
#     # First aggregate all false positive rates
#     all_fpr = np.unique(np.concatenate([fpr[i] for i in range(n_classes)]))

#     # Then interpolate all ROC curves at this points
#     mean_tpr = np.zeros_like(all_fpr)
#     for i in range(n_classes):
#         mean_tpr += np.interp(all_fpr, fpr[i], tpr[i])

#     # Finally average it and compute AUC
#     mean_tpr /= n_classes

#     fpr["macro"] = all_fpr
#     tpr["macro"] = mean_tpr
#     roc_auc["macro"] = auc(fpr["macro"], tpr["macro"])

#     plt.plot(fpr["macro"], tpr["macro"], lw=2,
#              label=f'{name} (Macro-Avg AUC = {roc_auc["macro"]:.2f})')

# # Garis baseline
# plt.plot([0, 1], [0, 1], color='gray', linestyle='--', lw=2)

# plt.xlim([0.0, 1.0])
# plt.ylim([0.0, 1.05])
# plt.xlabel('False Positive Rate')
# plt.ylabel('True Positive Rate')
# plt.title('Multiclass ROC Curve (Macro-Averaged) for Multiple Models')
# plt.legend(loc='lower right')
# plt.grid(True)
# plt.tight_layout()
# plt.show()

# # Opsional: Untuk melihat AUC per kelas (contoh untuk model pertama)
# print("\nAUC Per Class (for the first model in the list):")
# for i in range(n_classes):
#     print(f"Class {classes[i]} vs Rest: AUC = {roc_auc[i]:.2f}")

# %%
# import matplotlib.pyplot as plt
# import pandas as pd
# import numpy as np
# from sklearn.metrics import accuracy_score, f1_score, precision_score, recall_score, cohen_kappa_score

# results = {
#     'Naive Bayes': {
#         'Accuracy': accuracy_score(y_test, nb_pred),
#         'F1-Score': f1_score(y_test, nb_pred, average='weighted'),
#         'Precision': precision_score(y_test, nb_pred, average='weighted'),
#         'Recall': recall_score(y_test, nb_pred, average='weighted'),
#         'Kappa': cohen_kappa_score(y_test, nb_pred) # Tambahkan Kappa di sini
#     },
#     'Random Forest': {
#         'Accuracy': accuracy_score(y_test, rf_pred),
#         'F1-Score': f1_score(y_test, rf_pred, average='weighted'),
#         'Precision': precision_score(y_test, rf_pred, average='weighted'),
#         'Recall': recall_score(y_test, rf_pred, average='weighted'),
#         'Kappa': cohen_kappa_score(y_test, rf_pred)
#     },
#     'XGBoost': {
#         'Accuracy': accuracy_score(y_test, y_pred_xgb),
#         'F1-Score': f1_score(y_test, y_pred_xgb, average='weighted'),
#         'Precision': precision_score(y_test, y_pred_xgb, average='weighted'),
#         'Recall': recall_score(y_test, y_pred_xgb, average='weighted'),
#         'Kappa': cohen_kappa_score(y_test, y_pred_xgb)
#     },
#     'AdaBoost': {
#         'Accuracy': accuracy_score(y_test, y_pred_ada),
#         'F1-Score': f1_score(y_test, y_pred_ada, average='weighted'),
#         'Precision': precision_score(y_test, y_pred_ada, average='weighted'),
#         'Recall': recall_score(y_test, y_pred_ada, average='weighted'),
#         'Kappa': cohen_kappa_score(y_test, y_pred_ada)
#     },
#     'SVM': {
#         'Accuracy': accuracy_score(y_test, y_pred_svm),
#         'F1-Score': f1_score(y_test, y_pred_svm, average='weighted'),
#         'Precision': precision_score(y_test, y_pred_svm, average='weighted'),
#         'Recall': recall_score(y_test, y_pred_svm, average='weighted'),
#         'Kappa': cohen_kappa_score(y_test, y_pred_svm)
#     },
#     'KNN': {
#         'Accuracy': accuracy_score(y_test, y_pred_knn),
#         'F1-Score': f1_score(y_test, y_pred_knn, average='weighted'),
#         'Precision': precision_score(y_test, y_pred_knn, average='weighted'),
#         'Recall': recall_score(y_test, y_pred_knn, average='weighted'),
#         'Kappa': cohen_kappa_score(y_test, y_pred_knn)
#     },
#     'Logistic': {
#         'Accuracy': accuracy_score(y_test, y_pred_logreg),
#         'F1-Score': f1_score(y_test, y_pred_logreg, average='weighted'),
#         'Precision': precision_score(y_test, y_pred_logreg, average='weighted'),
#         'Recall': recall_score(y_test, y_pred_logreg, average='weighted'),
#         'Kappa': cohen_kappa_score(y_test, y_pred_logreg)
#     },
#     'Ensemble Stacking':{
#         'Accuracy': accuracy_score(y_test, y_pred_stack),
#         'F1-Score': f1_score(y_test, y_pred_stack, average='weighted'),
#         'Precision': precision_score(y_test, y_pred_stack, average='weighted'),
#         'Recall': recall_score(y_test, y_pred_stack, average='weighted'),
#         'Kappa': cohen_kappa_score(y_test, y_pred_stack)
#     }
# }

# # Convert dictionary ke DataFrame
# results_df = pd.DataFrame.from_dict(results, orient='index').reset_index()
# results_df.columns = ['Model', 'Accuracy', 'F1-Score', 'Precision', 'Recall', 'Kappa'] # Tambahkan 'Kappa' di sini

# # Urutkan berdasarkan Kappa (karena kita akan memplot Kappa)
# results_df = results_df.sort_values(by='Kappa', ascending=False)

# print("--- Hasil Metrik Model (dengan Kappa) ---")
# print(results_df)

# # --- Kode untuk Plotting Kappa ---
# plt.figure(figsize=(12, 7)) # Ukuran plot

# # Membuat bar chart untuk Kappa
# plt.bar(results_df['Model'], results_df['Kappa'], color='lightcoral')

# # Menambahkan label nilai Kappa di atas setiap bar
# for i, kappa_val in enumerate(results_df['Kappa']):
#     plt.text(i, kappa_val + 0.005, f'{kappa_val:.4f}', ha='center', va='bottom', fontsize=9)

# plt.xlabel('Model')
# plt.ylabel('Cohen\'s Kappa')
# plt.title('Perbandingan Cohen\'s Kappa antar Model Klasifikasi')
# plt.ylim(results_df['Kappa'].min() * 0.95, 1.0) # Sesuaikan batas Y, Kappa bisa negatif tapi umumnya positif
# plt.xticks(rotation=45, ha='right') # Rotasi label X agar tidak tumpang tindih
# plt.tight_layout() # Mengatur tata letak agar semua elemen terlihat
# plt.grid(axis='y', linestyle='--', alpha=0.7) # Menambahkan grid horizontal

# # Simpan plot (opsional)
# plt.savefig('kappa_model_perbandingan.png')

# # Tampilkan plot
# plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from sklearn.metrics import accuracy_score, f1_score, precision_score, recall_score, cohen_kappa_score

# --- ASUMSI: y_test dan semua variabel prediksi (nb_pred, rf_pred, dst.) sudah tersedia. ---
# Ini adalah bagian yang harus Anda pastikan sudah dijalankan di notebook/script Anda.
# Saya akan menggunakan dummy data untuk memastikan kode ini bisa dijalankan secara mandiri.
# HAPUS BAGIAN INI JIKA ANDA SUDAH MEMILIKI DATA PREDIKSI DAN y_test SEBENARNYA.
from sklearn.model_selection import train_test_split
from sklearn.datasets import make_classification
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier, AdaBoostClassifier, StackingClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.svm import SVC
# --- AKHIR DUMMY DATA ---

# Buat dictionary dengan semua metrik, termasuk Kappa
results = {
    'Naive Bayes': {
        'Accuracy': accuracy_score(y_test, nb_pred),
        'F1-Score': f1_score(y_test, nb_pred, average='weighted'),
        'Precision': precision_score(y_test, nb_pred, average='weighted'),
        'Recall': recall_score(y_test, nb_pred, average='weighted'),
        'Kappa': cohen_kappa_score(y_test, nb_pred)
    },
    'Random Forest': {
        'Accuracy': accuracy_score(y_test, rf_pred),
        'F1-Score': f1_score(y_test, rf_pred, average='weighted'),
        'Precision': precision_score(y_test, rf_pred, average='weighted'),
        'Recall': recall_score(y_test, rf_pred, average='weighted'),
        'Kappa': cohen_kappa_score(y_test, rf_pred)
    },
    'XGBoost': {
        'Accuracy': accuracy_score(y_test, y_pred_xgb),
        'F1-Score': f1_score(y_test, y_pred_xgb, average='weighted'),
        'Precision': precision_score(y_test, y_pred_xgb, average='weighted'),
        'Recall': recall_score(y_test, y_pred_xgb, average='weighted'),
        'Kappa': cohen_kappa_score(y_test, y_pred_xgb)
    },
    'AdaBoost': {
        'Accuracy': accuracy_score(y_test, y_pred_ada),
        'F1-Score': f1_score(y_test, y_pred_ada, average='weighted'),
        'Precision': precision_score(y_test, y_pred_ada, average='weighted'),
        'Recall': recall_score(y_test, y_pred_ada, average='weighted'),
        'Kappa': cohen_kappa_score(y_test, y_pred_ada)
    },
    # 'SVM': {
    #     'Accuracy': accuracy_score(y_test, y_pred_svm),
    #     'F1-Score': f1_score(y_test, y_pred_svm, average='weighted'),
    #     'Precision': precision_score(y_test, y_pred_svm, average='weighted'),
    #     'Recall': recall_score(y_test, y_pred_svm, average='weighted'),
    #     'Kappa': cohen_kappa_score(y_test, y_pred_svm)
    # },
    'KNN': {
        'Accuracy': accuracy_score(y_test, y_pred_knn),
        'F1-Score': f1_score(y_test, y_pred_knn, average='weighted'),
        'Precision': precision_score(y_test, y_pred_knn, average='weighted'),
        'Recall': recall_score(y_test, y_pred_knn, average='weighted'),
        'Kappa': cohen_kappa_score(y_test, y_pred_knn)
    },
    'Logistic': {
        'Accuracy': accuracy_score(y_test, y_pred_logreg),
        'F1-Score': f1_score(y_test, y_pred_logreg, average='weighted'),
        'Precision': precision_score(y_test, y_pred_logreg, average='weighted'),
        'Recall': recall_score(y_test, y_pred_logreg, average='weighted'),
        'Kappa': cohen_kappa_score(y_test, y_pred_logreg)
    },
    # 'Ensemble Stacking':{
    #     'Accuracy': accuracy_score(y_test, y_pred_stack),
    #     'F1-Score': f1_score(y_test, y_pred_stack, average='weighted'),
    #     'Precision': precision_score(y_test, y_pred_stack, average='weighted'),
    #     'Recall': recall_score(y_test, y_pred_stack, average='weighted'),
    #     'Kappa': cohen_kappa_score(y_test, y_pred_stack)
    # }
}

# Convert dictionary ke DataFrame
results_df = pd.DataFrame.from_dict(results, orient='index').reset_index()
results_df.columns = ['Model', 'Accuracy', 'F1-Score', 'Precision', 'Recall', 'Kappa']

print("--- Hasil Metrik Model Lengkap ---")
print(results_df.sort_values(by='Accuracy', ascending=False)) # Tampilkan yang diurutkan by Akurasi

# --- Plotting F1-Score, Precision, dan Recall secara Bersamaan --- 
df_combined_sorted = results_df.sort_values(by='F1-Score', ascending=False)

x = np.arange(len(df_combined_sorted['Model']))  # Posisi model di sumbu X
width = 0.25  # Lebar bar per grup

fig, ax = plt.subplots(figsize=(15, 8))

# Plot F1-Score
rects1 = ax.bar(x - width, df_combined_sorted['F1-Score'], width, label='F1-Score', color='skyblue')

# Plot Precision
rects2 = ax.bar(x, df_combined_sorted['Precision'], width, label='Precision', color='lightgreen')

# Plot Recall
rects3 = ax.bar(x + width, df_combined_sorted['Recall'], width, label='Recall', color='salmon')

# Fungsi untuk menambahkan nilai di atas setiap bar
def autolabel(rects):
    for rect in rects:
        height = rect.get_height()
        ax.annotate(f'{height:.3f}',
                    xy=(rect.get_x() + rect.get_width() / 2, height),
                    xytext=(0, 3),  # Jarak vertikal dari bar
                    textcoords="offset points",
                    ha='center', va='bottom', fontsize=8)

autolabel(rects1)
autolabel(rects2)
autolabel(rects3)

# Label dan tampilan sumbu
ax.set_xlabel('Model')
ax.set_ylabel('Score')
ax.set_title('Perbandingan F1-Score, Precision, dan Recall antar Model Klasifikasi')
ax.set_xticks(x)
ax.set_xticklabels(df_combined_sorted['Model'], rotation=45, ha='right')
ax.legend()

# Set batas Y otomatis menyesuaikan
min_val = min(df_combined_sorted[['F1-Score', 'Precision', 'Recall']].min())
ax.set_ylim(min_val * 0.95, 1.0)

plt.tight_layout()
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.savefig('f1_precision_recall_comparison.png')
plt.show()
# Out:
# --- Hasil Metrik Model Lengkap ---
#            Model  Accuracy  F1-Score  Precision    Recall     Kappa
# 1  Random Forest  0.925277  0.926241   0.928164  0.925277  0.906596
# 2        XGBoost  0.924375  0.926189   0.932350  0.924375  0.905475
# 5       Logistic  0.903118  0.900474   0.901015  0.903118  0.878851
# 3       AdaBoost  0.894099  0.896142   0.907334  0.894099  0.867617
# 0    Naive Bayes  0.842309  0.831565   0.847594  0.842309  0.802683
# 4            KNN  0.819119  0.827804   0.853478  0.819119  0.774012
